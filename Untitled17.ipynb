# %% [markdown]
# <a href="https://colab.research.google.com/github/jborri/Javascript-Class/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import time


def search_whit_artworks(title_contains=None):
    """
    Search for artworks by keyword.

    Args:
        query: Search term (e.g., "impressionism", "cats", "van gogh")

    Returns:
        List of artwork IDs
    """
    print(f"Searching for artworks about '{title_contains}'...")

    base_url = "https://whitney.org/api"
    search_url = f"{base_url}/artworks"
    params = {"q[title_cont]": title_contains}

    try:
        response = requests.get(search_url, params=params)

        if response.status_code == 200:
            data = response.json()

            artworks_data = data.get("data", [])
            object_ids = [artwork['id'] for artwork in artworks_data]
            total = len(object_ids)

            print(f"Found {total} artworks")
            return object_ids
        else:
            print(f"Search failed with status {response.status_code}")
            return []

    except requests.exceptions.RequestException as e:
        print(f"Network error: {e}")
        return []

def get_whit_artwork_details(object_ids):
    """
    Get detailed information about a specific artwork from the Whitney API.

    Args:
        artwork_id: The Whitney Museum's ID for the artwork

    Returns:
        Dictionary with artwork details
    """
    base_url = "https://whitney.org/api"
    url = f"{base_url}/artworks/{object_ids}"

    try:
        response = requests.get(url)

        if response.status_code == 200:
            return response.json()
        else:
            print(f"Could not get details for artwork {object_ids}") # Corrected variable name from artwork_id to object_ids
            return None

    except requests.exceptions.RequestException as e:
        print(f"Network error: {e}")
        return None
search_term = input("Enter a search term for artworks: ")


print(f"\nFetching artworks with '{search_term}' in title...")
artworks_data = search_whit_artworks(title_contains=search_term)
print(f"Artworks with '{search_term}':", artworks_data)

detailed_artworks = []
for artwork_id in artworks_data:
    print(f"Fetching details for artwork ID: {artwork_id}")
    details = get_whit_artwork_details(artwork_id)
    if details:
        detailed_artworks.append(details)
    else:
        print(f"Could not retrieve details for artwork {artwork_id}")
print(f"Successfully fetched details for {len(detailed_artworks)} artworks.")

print("\nSummary of artworks:")
print("-" * 30)
for i, artwork_details in enumerate(detailed_artworks):
    artwork = artwork_details['data']['attributes']
    artist_text = artwork.get('display_artist_text', 'Unknown Artist')
    print(f"Artwork {i+1}:")
    print(f"  Title: {artwork.get('title', 'N/A')}")
    print(f"  Artist: {artist_text}")
    print(f"  Date: {artwork.get('display_date', 'N/A')}")
    print(f"  Medium: {artwork.get('medium', 'N/A')}")
    print(f"  Department: {artwork.get('department', 'N/A')}")
    print(f"  Classification: {artwork.get('classification', 'N/A')}")
    print("-" * 30)
# Out:
# Enter a search term for artworks: painting
#
# Fetching artworks with 'painting' in title...
# Searching for artworks about 'painting'...
# Found 30 artworks
# Artworks with 'painting': ['2924', '56092', '2322', '19930', '19929', '61021', '47108', '57974', '42597', '42587', '42586', '68601', '469', '11688', '654', '11687', '11684', '912', '11686', '11683', '1809', '62185', '49783', '46593', '46594', '46592', '37694', '37833', '37831', '37830']
# Fetching details for artwork ID: 2924
# Fetching details for artwork ID: 56092
# Fetching details for artwork ID: 2322
# Fetching details for artwork ID: 19930
# Fetching details for artwork ID: 19929
# Fetching details for artwork ID: 61021
# Fetching details for artwork ID: 47108
# Fetching details for artwork ID: 57974
# Fetching details for artwork ID: 42597
# Fetching details for artwork ID: 42587
# Fetching details for artwork ID: 42586
# Fetching details for artwork ID: 68601
# Fetching details for artwork ID: 469
# Fetching details for artwork ID: 11688
# Fetching details for artwork ID: 654
# Fetching details for artwork ID: 11687
# Fetching details for artwork ID: 11684
# Fetching details for artwork ID: 912
# Fetching details for artwork ID: 11686
# Fetching details for artwork ID: 11683
# Fetching details for artwork ID: 1809
# Fetching details for artwork ID: 62185
# Fetching details for artwork ID: 49783
# Fetching details for artwork ID: 46593
# Fetching details for artwork ID: 46594
# Fetching details for artwork ID: 46592
# Fetching details for artwork ID: 37694
# Fetching details for artwork ID: 37833
# Fetching details for artwork ID: 37831
# Fetching details for artwork ID: 37830
# Successfully fetched details for 30 artworks.
#
# Summary of artworks:
# ------------------------------
# Artwork 1:
#   Title: Little Big Painting
#   Artist: Roy Lichtenstein
#   Date: 1965
#   Medium: Oil and acrylic on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 2:
#   Title: Painting
#   Artist: Torey Thornton
#   Date: 2017
#   Medium: Steel saw blade and painted rocks
#   Department: collection
#   Classification: Sculpture
# ------------------------------
# Artwork 3:
#   Title: Painting
#   Artist: Arshile Gorky
#   Date: 1936–1937
#   Medium: Oil on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 4:
#   Title: Camera Obscura Image of Windows in Gallery with Hopper Painting, Whitney Museum of American Art [Edward Hopper, Woman in the Sun, 1961]
#   Artist: Abelardo Morell
#   Date: 2003
#   Medium: Gelatin silver print
#   Department: collection
#   Classification: Photographs
# ------------------------------
# Artwork 5:
#   Title: Camera Obscura Image of Windows in Gallery with Two Paintings, Whitney Museum of American Art [Edward Hopper, Woman in the Sun, 1961 and Roy Lichtenstein, Girl in Window (Study for World’s Fair Mural) © Estate of Roy Lichtenstein, 1963]
#   Artist: Abelardo Morell
#   Date: 2003
#   Medium: Gelatin silver print
#   Department: collection
#   Classification: Photographs
# ------------------------------
# Artwork 6:
#   Title: Two Paintings: Sleeping Muse
#   Artist: Roy Lichtenstein
#   Date: 1984
#   Medium: Woodcut, lithograph, screenprint, and collage on paper
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 7:
#   Title: Representational Painting
#   Artist: Eleanor Antin
#   Date: 1971
#   Medium: Video, black-and-white, silent, 38 min.
#   Department: collection
#   Classification: Video
# ------------------------------
# Artwork 8:
#   Title: Painting With History In A Room Filled With People With Funny Names 3
#   Artist: Korakrit Arunanondchai
#   Date: 2015
#   Medium: Video installation, color, sound, 25:29 min., with denim pillows
#   Department: special
#   Classification: Installations
# ------------------------------
# Artwork 9:
#   Title: Painting Room Lights
#   Artist: David Haxton
#   Date: 1981
#   Medium: 16mm film, color, silent, 8:50 min., transferred to video
#   Department: collection
#   Classification: Film
# ------------------------------
# Artwork 10:
#   Title: Painting Lights
#   Artist: David Haxton
#   Date: 1976
#   Medium: 16mm film, black-and-white, silent, 6:58 min., transferred to video
#   Department: collection
#   Classification: Film
# ------------------------------
# Artwork 11:
#   Title: Painting in Object
#   Artist: David Haxton
#   Date: 1975–1976
#   Medium: 16mm film, black-and-white, silent, 5:33 min., transferred to video
#   Department: collection
#   Classification: Film
# ------------------------------
# Artwork 12:
#   Title: Jacob Lawrence, Romare Bearden, American Painting
#   Artist: Raymond Saunders
#   Date: 1988
#   Medium: Paint and found papers and objects on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 13:
#   Title: Relational Painting
#   Artist: Fritz Glarner
#   Date: 1949–1951
#   Medium: Oil on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 14:
#   Title: Abstract Painting
#   Artist: Ad Reinhardt
#   Date: 1960–1966
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 15:
#   Title: Abstract Painting, Number 33
#   Artist: Ad Reinhardt
#   Date: 1963
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 16:
#   Title: Abstract Painting
#   Artist: Ad Reinhardt
#   Date: 1960–1966
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 17:
#   Title: Abstract Painting, Red
#   Artist: Ad Reinhardt
#   Date: 1952
#   Medium: Oil on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 18:
#   Title: Abstract Painting, Blue 1953
#   Artist: Ad Reinhardt
#   Date: 1953
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 19:
#   Title: Abstract Painting
#   Artist: Ad Reinhardt
#   Date: 1960–1966
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 20:
#   Title: Abstract Painting
#   Artist: Ad Reinhardt
#   Date: 1940
#   Medium: Oil on canvas
#   Department: special
#   Classification: Paintings
# ------------------------------
# Artwork 21:
#   Title: Painting, Number 5
#   Artist: Marsden Hartley
#   Date: 1914–1915
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 22:
#   Title: Interior with Mobile Painting (Study)
#   Artist: Roy Lichtenstein
#   Date: 1991
#   Medium: Graphite on polyester tracing film
#   Department: collection
#   Classification: Drawings
# ------------------------------
# Artwork 23:
#   Title: Alex Katz Painting Rudy and Yvonne 1, Lincolnville, Maine
#   Artist: Rudy Burckhardt
#   Date: c. 1978
#   Medium: Gelatin silver print
#   Department: collection
#   Classification: Photographs
# ------------------------------
# Artwork 24:
#   Title: Painting with History in a room filled with men with funny names 2 (Mango and Sticky Rice)
#   Artist: Korakrit Arunanondchai
#   Date: 2014
#   Medium: Video, color, sound, 2:46 min.
#   Department: collection
#   Classification: Video
# ------------------------------
# Artwork 25:
#   Title: Painting with History in a room filled with men with funny names 2 (Twin)
#   Artist: Korakrit Arunanondchai
#   Date: 2014
#   Medium: Video, color, sound, 1:01 min.
#   Department: collection
#   Classification: Video
# ------------------------------
# Artwork 26:
#   Title: Painting with History in a room filled with men with funny names 2 (Hug of the Bangkokboy)
#   Artist: Korakrit Arunanondchai
#   Date: 2014
#   Medium: Video, color, sound, 8:48 min.
#   Department: collection
#   Classification: Video
# ------------------------------
# Artwork 27:
#   Title: What This Painting Aims to Do
#   Artist: John Baldessari
#   Date: 1966–1968
#   Medium: Acrylic and oil on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 28:
#   Title: Painting with Two Balls (Grays)
#   Artist: Jasper Johns
#   Date: 1971
#   Medium: Screenprint
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 29:
#   Title: Painting with Two Balls (Grays)
#   Artist: Jasper Johns
#   Date: 1971
#   Medium: Screenprint
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 30:
#   Title: Painting with Two Balls
#   Artist: Jasper Johns
#   Date: 1971
#   Medium: Screenprint
#   Department: collection
#   Classification: Prints
# ------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt

classifications = []
departments = []

for artwork_details in detailed_artworks:
    artwork = artwork_details['data']['attributes']
    classifications.append(artwork.get('classification', 'Unknown'))
    departments.append(artwork.get('department', 'Unknown'))

#creating dataframe
df = pd.DataFrame({
    'Classification': classifications,
    'Department': departments
})

#plotting Classification
plt.figure(figsize=(12, 6))
df['Classification'].value_counts().plot(kind='bar')
plt.title('Distribution of Artworks by Classification')
plt.xlabel('Classification')
plt.ylabel('Number of Artworks')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#plotting Department
plt.figure(figsize=(10, 5))
df['Department'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Artworks by Department')
plt.xlabel('Department')
plt.ylabel('Number of Artworks')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
