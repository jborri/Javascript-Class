# %% [markdown]
# <a href="https://colab.research.google.com/github/jborri/Javascript-Class/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import time


def search_whit_artworks(title_contains=None):
    """
    Search for artworks by keyword.

    Args:
        query: Search term (e.g., "impressionism", "cats", "van gogh")

    Returns:
        List of artwork IDs
    """
    print(f"Searching for artworks about '{title_contains}'...")

    base_url = "https://whitney.org/api"
    search_url = f"{base_url}/artworks"
    params = {"q[title_cont]": title_contains}

    try:
        response = requests.get(search_url, params=params)

        if response.status_code == 200:
            data = response.json()

            artworks_data = data.get("data", [])
            object_ids = [artwork['id'] for artwork in artworks_data]
            total = len(object_ids)

            print(f"Found {total} artworks")
            return object_ids
        else:
            print(f"Search failed with status {response.status_code}")
            return []

    except requests.exceptions.RequestException as e:
        print(f"Network error: {e}")
        return []

def get_whit_artwork_details(object_ids):
    """
    Get detailed information about a specific artwork from the Whitney API.

    Args:
        artwork_id: The Whitney Museum's ID for the artwork

    Returns:
        Dictionary with artwork details
    """
    base_url = "https://whitney.org/api"
    url = f"{base_url}/artworks/{object_ids}"

    try:
        response = requests.get(url)

        if response.status_code == 200:
            return response.json()
        else:
            print(f"Could not get details for artwork {object_ids}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"Network error: {e}")
        return None
search_term = input("Enter a search term for artworks: ")


print(f"\nFetching artworks with '{search_term}' in title...")
artworks_data = search_whit_artworks(title_contains=search_term)
print(f"Artworks with '{search_term}':", artworks_data)

detailed_artworks = []
for artwork_id in artworks_data:
    print(f"Fetching details for artwork ID: {artwork_id}")
    details = get_whit_artwork_details(artwork_id)
    if details:
        detailed_artworks.append(details)
    else:
        print(f"Could not retrieve details for artwork {artwork_id}")
print(f"Successfully fetched details for {len(detailed_artworks)} artworks.")

print("\nSummary of artworks:")
print("-" * 30)
for i, artwork_details in enumerate(detailed_artworks):
    artwork = artwork_details['data']['attributes']
    artist_text = artwork.get('display_artist_text', 'Unknown Artist')
    print(f"Artwork {i+1}:")
    print(f"  Title: {artwork.get('title', 'N/A')}")
    print(f"  Artist: {artist_text}")
    print(f"  Date: {artwork.get('display_date', 'N/A')}")
    print(f"  Medium: {artwork.get('medium', 'N/A')}")
    print(f"  Department: {artwork.get('department', 'N/A')}")
    print(f"  Classification: {artwork.get('classification', 'N/A')}")
    print("-" * 30)
# Out:
# Enter a search term for artworks: green
#
# Fetching artworks with 'green' in title...
# Searching for artworks about 'green'...
# Found 30 artworks
# Artworks with 'green': ['415', '3253', '2092', '42968', '4092', '69753', '42592', '872', '69347', '25160', '67026', '13874', '10243', '55437', '22527', '37838', '29702', '5050', '37738', '16333', '30566', '45788', '67946', '1946', '11321', '12418', '5388', '6169', '16298', '67949']
# Fetching details for artwork ID: 415
# Fetching details for artwork ID: 3253
# Fetching details for artwork ID: 2092
# Fetching details for artwork ID: 42968
# Fetching details for artwork ID: 4092
# Fetching details for artwork ID: 69753
# Fetching details for artwork ID: 42592
# Fetching details for artwork ID: 872
# Fetching details for artwork ID: 69347
# Fetching details for artwork ID: 25160
# Fetching details for artwork ID: 67026
# Fetching details for artwork ID: 13874
# Fetching details for artwork ID: 10243
# Fetching details for artwork ID: 55437
# Fetching details for artwork ID: 22527
# Fetching details for artwork ID: 37838
# Fetching details for artwork ID: 29702
# Fetching details for artwork ID: 5050
# Fetching details for artwork ID: 37738
# Fetching details for artwork ID: 16333
# Fetching details for artwork ID: 30566
# Fetching details for artwork ID: 45788
# Fetching details for artwork ID: 67946
# Fetching details for artwork ID: 1946
# Fetching details for artwork ID: 11321
# Fetching details for artwork ID: 12418
# Fetching details for artwork ID: 5388
# Fetching details for artwork ID: 6169
# Fetching details for artwork ID: 16298
# Fetching details for artwork ID: 67949
# Successfully fetched details for 30 artworks.
#
# Summary of artworks:
# ------------------------------
# Artwork 1:
#   Title: It Was Blue and Green
#   Artist: Georgia O'Keeffe
#   Date: 1960
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 2:
#   Title: Green Coca-Cola Bottles
#   Artist: Andy Warhol
#   Date: 1962
#   Medium: Acrylic, screenprint, and graphite pencil on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 3:
#   Title: S. L. Green
#   Artist: Kenneth Price
#   Date: 1963
#   Medium: Painted ceramic, and wooden base
#   Department: collection
#   Classification: Sculpture
# ------------------------------
# Artwork 4:
#   Title: Rigoulot, the Strong Man: Green felt
#   Artist: Alexander Calder
#   Date: 1926–1931
#   Medium: Felt
#   Department: collection
#   Classification: Sculpture
# ------------------------------
# Artwork 5:
#   Title: Old Greenwich Village
#   Artist: Mabel Dwight
#   Date: 1928
#   Medium: Lithograph
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 6:
#   Title: CONTACTS 12, Green, New York, New York
#   Artist: Ken Ohara
#   Date: 1974–1976
#   Medium: Gelatin silver print
#   Department: collection
#   Classification: Photographs
# ------------------------------
# Artwork 7:
#   Title: White Red and Green Lights
#   Artist: David Haxton
#   Date: 1978
#   Medium: 16mm film, silent, color, 7:35 min., transferred to video
#   Department: collection
#   Classification: Film
# ------------------------------
# Artwork 8:
#   Title: Backyards, Greenwich Village
#   Artist: John Sloan
#   Date: 1914
#   Medium: Oil on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 9:
#   Title: Greenhouse Britain, 2011
#   Artist: The Harrisons
#   Date: 2011
#   Medium: Portfolio of three screenprints; two etching and aquatints; and two digital prints, with chine collé; and six digital prints with artist's text
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 10:
#   Title: Untitled (Double Green)
#   Artist: Joel Shapiro
#   Date: 1980
#   Medium: Lithograph
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 11:
#   Title: Evergreen
#   Artist: Dawoud Bey
#   Date: 2021
#   Medium: Three-channel video installation, color, sound, 10:58 min.
#   Department: collection
#   Classification: Installations
# ------------------------------
# Artwork 12:
#   Title: The Green Box (The Bride Stripped Bare by Her Bachelors, Even)
#   Artist: Marcel Duchamp
#   Date: 1934
#   Medium: Mixed media
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 13:
#   Title: Big Green
#   Artist: Alfred Leslie
#   Date: 1957
#   Medium: Oil and enamel on linen, four parts
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 14:
#   Title: Green Field
#   Artist: Alex Katz
#   Date: 1958
#   Medium: Collage and watercolor
#   Department: special
#   Classification: Drawings
# ------------------------------
# Artwork 15:
#   Title: 7-Up, Pink Characters, Green Background
#   Artist: Claes Oldenburg
#   Date: 1972
#   Medium: Pastel and wax crayon on paper
#   Department: collection
#   Classification: Drawings
# ------------------------------
# Artwork 16:
#   Title: Green Angel
#   Artist: Jasper Johns
#   Date: 1991
#   Medium: Color etching
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 17:
#   Title: Untitled (Lavender Butterfly/Jacaranda over Light Green)
#   Artist: Mark Grotjahn
#   Date: 2004
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 18:
#   Title: Sixth Avenue, Greenwich Village
#   Artist: John Sloan
#   Date: 1923
#   Medium: Etching
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 19:
#   Title: Iceberg #36, Disko Bay, Greenland 2000
#   Artist: Lynn Davis
#   Date: 2000, printed 2002
#   Medium: Gelatin silver print
#   Department: collection
#   Classification: Photographs
# ------------------------------
# Artwork 20:
#   Title: Art Make-Up No 3: Green
#   Artist: Bruce Nauman
#   Date: 1967–1968
#   Medium: Four-screen 16mm film installation, color, silent, 10 min., transferred to video
#   Department: collection
#   Classification: Installations
# ------------------------------
# Artwork 21:
#   Title: Green Horses
#   Artist: Bruce Nauman
#   Date: 1988
#   Medium: Video installation, color, sound, 59:40 min. looped, with two color video monitors, two DVD players, video projector, and chair
#   Department: collection
#   Classification: Installations
# ------------------------------
# Artwork 22:
#   Title: Green Screen #7
#   Artist: Liz Deschenes
#   Date: 2001
#   Medium: Silver halide print mounted on plexiglass
#   Department: collection
#   Classification: Photographs
# ------------------------------
# Artwork 23:
#   Title: Study for "Green Blue Red"
#   Artist: Ellsworth Kelly
#   Date: 1963
#   Medium: Oil on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 24:
#   Title: Harbor and Green Cloth, II
#   Artist: Nell Blaine
#   Date: 1958
#   Medium: Oil on linen
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 25:
#   Title: Green Shoes
#   Artist: Alex Katz
#   Date: 1987
#   Medium: Oil on composition board
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 26:
#   Title: Vivienne in the green dress
#   Artist: Nan Goldin
#   Date: 1980
#   Medium: Silver dye bleach print
#   Department: collection
#   Classification: Photographs
# ------------------------------
# Artwork 27:
#   Title: The Green Hell
#   Artist: H.C. Westermann
#   Date: 1975
#   Medium: Woodcut
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 28:
#   Title: The Green Cap
#   Artist: Alex Katz
#   Date: 1985
#   Medium: Woodcut
#   Department: collection
#   Classification: Prints
# ------------------------------
# Artwork 29:
#   Title: Green Hammer
#   Artist: Gene Davis
#   Date: 1968
#   Medium: Acrylic on canvas
#   Department: collection
#   Classification: Paintings
# ------------------------------
# Artwork 30:
#   Title: Blue, Green and Red
#   Artist: Ellsworth Kelly
#   Date: 1964
#   Medium: Oil on paper
#   Department: collection
#   Classification: Drawings
# ------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from datetime import datetime
import json

def save_report(analysis, filename):
    """Save analysis results to JSON."""
    with open(filename, "w") as file:
        json.dump(analysis, file, indent=2)
    print(f"Report saved to {filename}")

def generate_summary(analysis):
    """Generate human-readable summary."""
    summary = []
    summary.append("=" * 50)
    summary.append("SURVEY ANALYSIS REPORT")
    summary.append("=" * 50)
    summary.append(f"Total Responses: {analysis['total_responses']}")
    summary.append(f"\n {search_term} by DEPARTMENT:")

    for cat, count in analysis["categories"].items():
        percentage = (count / analysis["total_responses"]) * 100
        summary.append(f"  {cat}: {count} ({percentage:.1f}%)")

    summary.append(f"\n{search_term} by CLASSIFICATION:")

    for catClass, count in analysis["categoriesClass"].items():
        percentage = (count / analysis["total_responses"]) * 100
        summary.append(f"  {catClass}: {count} ({percentage:.1f}%)")

    summary.append(f"\n {search_term} by MEDIUM:")

    for catMed, count in analysis["categoriesMed"].items():
        percentage = (count / analysis["total_responses"]) * 100
        summary.append(f"  {catMed}: {count} ({percentage:.1f}%)")

    summary.append(f"\n {search_term.upper()} by COUNTRY:")

    for ctry, count in analysis["country"].items():
        percentage = (count / analysis["total_responses"]) * 100
        summary.append(f"  {ctry}: {count} ({percentage:.1f}%)")

    summary.append(f"\nAnalysis Date: {analysis['analysis_date']}")

    return "\n".join(summary)

# Initialize counters for analysis
department_counts = Counter()
classification_counts = Counter()
medium_counts = Counter()
artist_country_counts = Counter()

for artwork_details in detailed_artworks:
    artwork = artwork_details['data']['attributes']
    department_counts[artwork.get('department', 'Unknown')] += 1
    classification_counts[artwork.get('classification', 'Unknown')] += 1
    medium_counts[artwork.get('medium', 'Unknown')] += 1
    # As artist country is not directly available, using 'Unknown' for this example
    artist_country_counts['Unknown'] += 1

# Create the analysis dictionary
analysis = {
    'total_responses': len(detailed_artworks),
    'categories': dict(department_counts),
    'categoriesClass': dict(classification_counts),
    'categoriesMed': dict(medium_counts),
    'country': dict(artist_country_counts),
    'analysis_date': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
}

# Generate the summary report
summary_report = generate_summary(analysis)
print(summary_report)

# The previous plotting code for classifications and departments remains the same
classifications = []
departments = []
medium = [] # Initialize medium list

for artwork_details in detailed_artworks:
    artwork = artwork_details['data']['attributes']
    classifications.append(artwork.get('classification', 'Unknown'))
    departments.append(artwork.get('department', 'Unknown'))
    medium.append(artwork.get('medium', 'Unknown')) # Populate medium list

#creating dataframe
df = pd.DataFrame({
    'Classification': classifications,
    'Department': departments,
    'Medium': medium
})

#plotting Classification
plt.figure(figsize=(12, 6))
df['Classification'].value_counts().plot(kind='bar')
plt.title('Distribution of Artworks by Classification')
plt.xlabel('Classification')
plt.ylabel('Number of Artworks')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#plotting Department
plt.figure(figsize=(10, 5))
df['Department'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Artworks by Department')
plt.xlabel('Department')
plt.ylabel('Number of Artworks')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#plotting Medium
plt.figure(figsize=(10, 5))
df['Medium'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('Distribution of Artworks by Medium')
plt.xlabel('Medium')
plt.ylabel('Number of Artworks')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ==================================================
# SURVEY ANALYSIS REPORT
# ==================================================
# Total Responses: 30
#
#  green by DEPARTMENT:
#   collection: 29 (96.7%)
#   special: 1 (3.3%)
#
# green by CLASSIFICATION:
#   Paintings: 9 (30.0%)
#   Sculpture: 2 (6.7%)
#   Prints: 8 (26.7%)
#   Photographs: 4 (13.3%)
#   Film: 1 (3.3%)
#   Installations: 3 (10.0%)
#   Drawings: 3 (10.0%)
#
#  green by MEDIUM:
#   Oil on linen: 3 (10.0%)
#   Acrylic, screenprint, and graphite pencil on canvas: 1 (3.3%)
#   Painted ceramic, and wooden base: 1 (3.3%)
#   Felt: 1 (3.3%)
#   Lithograph: 2 (6.7%)
#   Gelatin silver print: 2 (6.7%)
#   16mm film, silent, color, 7:35 min., transferred to video: 1 (3.3%)
#   Oil on canvas: 2 (6.7%)
#   Portfolio of three screenprints; two etching and aquatints; and two digital prints, with chine collé; and six digital prints with artist's text: 1 (3.3%)
#   Three-channel video installation, color, sound, 10:58 min.: 1 (3.3%)
#   Mixed media: 1 (3.3%)
#   Oil and enamel on linen, four parts: 1 (3.3%)
#   Collage and watercolor: 1 (3.3%)
#   Pastel and wax crayon on paper: 1 (3.3%)
#   Color etching: 1 (3.3%)
#   Etching: 1 (3.3%)
#   Four-screen 16mm film installation, color, silent, 10 min., transferred to video: 1 (3.3%)
#   Video installation, color, sound, 59:40 min. looped, with two color video monitors, two DVD players, video projector, and chair: 1 (3.3%)
#   Silver halide print mounted on plexiglass: 1 (3.3%)
#   Oil on composition board: 1 (3.3%)
#   Silver dye bleach print: 1 (3.3%)
#   Woodcut: 2 (6.7%)
#   Acrylic on canvas: 1 (3.3%)
#   Oil on paper: 1 (3.3%)
#
#  GREEN by COUNTRY:
#   Unknown: 30 (100.0%)
#
# Analysis Date: 2025-12-18 23:59:36
# /tmp/ipython-input-791388331.py:121: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
